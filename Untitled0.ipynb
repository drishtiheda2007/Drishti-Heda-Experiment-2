# %% [markdown]
# <a href="https://colab.research.google.com/github/drishtiheda2007/Drishti-Heda-Experiment-2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Unit-1
# ## Basic Programs- Experiment 2

# %%
# First Python Program/ String
print("Hello, Welcome to Python Programming")
# Out:
# Hello, Welcome to Python Programming

# %%
a = "Hello"
print(a)
# Out:
# Hello

# %%
# Comments
#This is a comment.
print("Hello, World!")
# Out:
# Hello, World!

# %%
## Many Statements
print("Hello World!")
print("Have a good day.")
print("Learning Pyhton is fun!")
# Out:
# Hello World!
# Have a good day.
# Learning Pyhton is fun!

# %%
print("Hello"); print("How are you?"); print("Bye bye!")
# Out:
# Hello
# How are you?
# Bye bye!

# %%
print("Python is fun!"); print("Really!")
# Out:
# Python is fun!
# Really!

# %%
print("Hello World", end=" ")
print("I will print on the same line.")
# Out:
# Hello World I will print on the same line.

# %%
#Print numbers
a=3
print(a)
print(369)
print(300.300)
# Out:
# 3
# 369
# 300.3

# %%
#Variables
x = 5
y = "Hello, World!"

print(x)
print(y)
# Out:
# 5
# Hello, World!

# %%
# Case-Sensitive
a = 4
A = "Sally"

print(a)
print(A)
# Out:
# 4
# Sally

# %%
#Many Values to Multiple Variables
x,y,z = "Orange", "Banana", "Cherry"

print(x)
print(y)
print(z)
# Out:
# Orange
# Banana
# Cherry

# %%
# Basic Arithmetic Operations
a = 10
b = 5

print("Addition =", a + b)
print("Subtraction =", a - b)
print("Multiplication =", a * b)
print("Division =", a / b)
# Out:
# Addition = 15
# Subtraction = 5
# Multiplication = 50
# Division = 2.0

# %%
# Understanding Data Types
x = 10
y = 3.14
z = "Python"
A = True
C=3+2j
print(type(x))
print(type(y))
print(type(z))
print(type(A))
print(type(C))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# <class 'complex'>

# %%
name = input("Enter your name: ")
print("Hello", name)
# Out:
# Enter your name: Drishti
# Hello Drishti

# %%
# Taking Input from User
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print("Name:", name)
print("Age:", age)
# Out:
# Enter your name: Drishti Heda
# Enter your age: 18
# Name: Drishti Heda
# Age: 18
